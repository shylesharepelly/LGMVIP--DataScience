# %% [markdown]
# <a href="https://colab.research.google.com/github/shylesharepelly/LGMVIP--DataScience/blob/main/EDA_terrorism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task - 4 Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# dataset link: https://bit.ly/2TK5Xn5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r'/content/globalterrorism.csv',encoding="latin")

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 7311  197901090003   1979       1     9        NaN         0        NaN
# 7312  197901090004   1979       1     9        NaN         0        NaN
# 7313  197901090007   1979       1     9        NaN         0        NaN
# 7314  197901100001   1979       1    10        NaN         0        NaN
# 7315  197901100002   1979       1    10        NaN         0        NaN
#
#       country     country_txt  region  ... addnotes scite1 scite2  scite3  \
# 7311      138         Myanmar       5  ...      NaN    NaN    NaN     NaN
# 7312       98           Italy       8  ...      NaN    NaN    NaN     NaN
# 7313      603  United Kingdom       8  ...      NaN    NaN    NaN     NaN
# 7314       98           Italy       8  ...      NaN    NaN    NaN     NaN
# 7315       98           Italy       8  ...      NaN    NaN    NaN     NaN
#
#       dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
data.describe()
# Out:
#             eventid        iyear       imonth         iday     extended  \
# count  7.316000e+03  7316.000000  7316.000000  7316.000000  7316.000000
# mean   1.975070e+11  1975.003417     6.523237    15.129579     0.029251
# std    2.676603e+08     2.675243     3.477868     9.053688     0.168521
# min    1.970000e+11  1970.000000     0.000000     0.000000     0.000000
# 25%    1.973041e+11  1973.000000     3.000000     7.000000     0.000000
# 50%    1.976031e+11  1976.000000     6.000000    15.000000     0.000000
# 75%    1.977103e+11  1977.000000    10.000000    23.000000     0.000000
# max    1.979011e+11  1979.000000    12.000000    31.000000     1.000000
#
#            country       region     latitude    longitude  specificity  ...  \
# count  7316.000000  7316.000000  7133.000000  7133.000000  7316.000000  ...
# mean    238.453390     5.899125    34.842112   -22.783191     1.139284  ...
# std     194.540953     3.290733    22.248928    52.465516     0.700851  ...
# ...

# %%
data.size
# Out:
# 987660

# %%
columns = data.columns.to_list()
print(columns)
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %% [markdown]
# renaming columns

# %%
data1 = pd.DataFrame(data, data.rename(columns={ 'success': 'Success', 'location': 'Location', 'iyear':'Year','imonth':'Month','extended':'Extended','iday':'Day','country_txt':'Country',
                   'country': 'Country_code', 'provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target',
                   'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','motive':'Motive','city':'City','latitude':'Latitude','longitude':'Longitude'},inplace=True))

# %%
data1.head()
# Out:
#         eventid  Year  Month  Day approxdate  Extended resolution  \
# 0  197000000001  1970      7    2        NaN         0        NaN
# 1  197000000002  1970      0    0        NaN         0        NaN
# 2  197001000001  1970      1    0        NaN         0        NaN
# 3  197001000002  1970      1    0        NaN         0        NaN
# 4  197001000003  1970      1    0        NaN         0        NaN
#
#    Country_code             Country  region  ... addnotes scite1 scite2  \
# 0            58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1           130              Mexico       1  ...      NaN    NaN    NaN
# 2           160         Philippines       5  ...      NaN    NaN    NaN
# 3            78              Greece       8  ...      NaN    NaN    NaN
# 4           101               Japan       4  ...      NaN    NaN    NaN
#
#    scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7316 entries, 0 to 7315
# Columns: 135 entries, eventid to related
# dtypes: float64(63), int64(18), object(54)
# memory usage: 7.5+ MB

# %%
data1.isnull().sum()
# Out:
# eventid          0
# Year             0
# Month            0
# Day              0
# approxdate    7300
#               ...
# INT_LOG          1
# INT_IDEO         1
# INT_MISC         1
# INT_ANY          1
# related       6847
# Length: 135, dtype: int64

# %% [markdown]
# city with most attacks

# %%
df=data1['City'].value_counts().to_frame().drop('Unknown').sort_values('City',axis=0,ascending=False).head(10)
df.plot(kind='bar',figsize=(20,10),color='red')
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Total attacks",fontsize=15)
plt.title("Top 10 most affected cities",fontsize=20)
plt.show()

# %% [markdown]
# Most affected Country

# %%
plt.subplots(figsize=(20,10))
index1=data1['Country'].value_counts()[:10].index
values1=data1['Country'].value_counts()[:10].values
sns.barplot(index1,values1,palette='rocket')
plt.title('Top 10 most affected countries', fontsize = 20)
plt.xlabel('Country', fontsize = 15)
plt.ylabel('Total attacks', fontsize = 15)
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# Most affected Regions

# %%
df1=data1['Region'].value_counts().to_frame().sort_values('Region',axis=0,ascending=False).head(10)
df1.plot(kind='bar',figsize=(20,10),color='green')
plt.xticks(rotation = 50)
plt.xlabel("Region",fontsize=15)
plt.ylabel("Total attacks",fontsize=15)
plt.title("Top 10 most affected regions",fontsize=20)
plt.show()

# %% [markdown]
# Most affected Group

# %%
df2=data1[['Group','Killed']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('Killed',ascending=False).head(10)
df2.plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 terrorist attack groups",fontsize=20)
plt.xlabel("Terrorist group",fontsize=20)
plt.ylabel("Total attacks",fontsize=20)
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# Most used attack type

# %%
data1['AttackType'].value_counts().plot(kind='bar',figsize=(20,10),color='orange')
plt.xticks(rotation = 50)
plt.xlabel("Attack Type",fontsize=15)
plt.ylabel("Total attacks",fontsize=15)
plt.title("Most used attack types",fontsize=20)
plt.show()

# %% [markdown]
# Conclusion:
#
# Most attacked city - Belfast
#
# Most attacked country - United Kingdom and United States
#
# Most attacked region - Western Europe
#
# Terrorist group with most attacks - Irish Republican Army
#
# Most used attack type - Bombing/Explosion
